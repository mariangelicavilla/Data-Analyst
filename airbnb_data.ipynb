# %% [markdown]
# ##Importacion de librerias

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %%
import seaborn as sb

# %%
import numpy as np

# %% [markdown]
# ## Analisis exploratorio de datos de airbnb de Madrid con pandas

# %% [markdown]
# Este es mi primer ejercicio de analisis de datos con python utilizando pandas y jupyter

# %%
#Abrir csv
data= pd.read_csv("madrid_data_airbnb_2023.csv")
data
# Out:
#                        id                                               name  \
# 0                    6369  Rental unit in Madrid · ★4.87 · 1 bedroom · 1 ...
# 1                   21853  Rental unit in Madrid · ★4.58 · 1 bedroom · 1 ...
# 2                  451174  casa particular in Madrid · ★4.71 · 1 bedroom ...
# 3                   24805  Rental unit in Madrid · ★4.90 · 6 bedrooms · 1...
# 4                  456165  Guest suite in Madrid · ★5.0 · 1 bedroom · 1 b...
# ...                   ...                                                ...
# 23519  908757271360095110  Rental unit in Madrid · ★New · 2 bedrooms · 2 ...
# 23520  908768034188159973  Rental unit in Madrid · ★New · 3 bedrooms · 3 ...
# 23521  908772325334371147  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 23522  908774672501330570  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 23523  908784742161639676  Rental unit in Madrid · ★New · 2 bedrooms · 2 ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              23524 non-null  int64
#  1   name                            23524 non-null  object
#  2   host_id                         23524 non-null  int64
#  3   host_name                       23521 non-null  object
#  4   neighbourhood_group             23524 non-null  object
#  5   neighbourhood                   23524 non-null  object
#  6   latitude                        23524 non-null  float64
#  7   longitude                       23524 non-null  float64
#  8   room_type                       23524 non-null  object
#  9   price                           23524 non-null  int64
#  10  minimum_nights                  23524 non-null  int64
#  11  number_of_reviews               23524 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.352400e+04  2.352400e+04  23524.000000  23524.000000  23524.000000
# mean   3.042946e+17  1.961414e+08     40.421424     -3.694248    149.095690
# std    3.772467e+17  1.713861e+08      0.023056      0.027727    973.954275
# min    6.369000e+03  7.952000e+03     40.331397     -3.835330      0.000000
# 25%    2.705431e+07  3.586593e+07     40.409523     -3.707461     50.000000
# 50%    4.842274e+07  1.398005e+08     40.420075     -3.701150     89.000000
# 75%    7.158394e+17  3.488715e+08     40.431062     -3.685967    143.000000
# max    9.100071e+17  5.188792e+08     40.536230     -3.543760  85110.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    23524.000000       23524.000000       18505.000000
# mean         7.463569          41.826560           1.773514
# std         33.011152          78.693929           1.877412
# ...

# %%
data.head(15)
# Out:
#         id                                               name    host_id  \
# 0     6369  Rental unit in Madrid · ★4.87 · 1 bedroom · 1 ...      13660
# 1    21853  Rental unit in Madrid · ★4.58 · 1 bedroom · 1 ...      83531
# 2   451174  casa particular in Madrid · ★4.71 · 1 bedroom ...    2240898
# 3    24805  Rental unit in Madrid · ★4.90 · 6 bedrooms · 1...  346366726
# 4   456165  Guest suite in Madrid · ★5.0 · 1 bedroom · 1 b...     617086
# 5    26825  Home in Madrid · ★4.72 · 1 bedroom · 1 bed · 1...     114340
# 6   459303  Rental unit in Madrid · ★4.56 · 1 bedroom · 1 ...    1408525
# 7   459362  Rental unit in Madrid · ★4.54 · 1 bedroom · 1 ...    1408525
# 8    29044  Rental unit in Madrid · 2 bedrooms · 2 beds · ...     124972
# 9   460898  Rental unit in Madrid · 3 bedrooms · 3 beds · ...    2290984
# 10   30320  Rental unit in Madrid · ★4.63 · 1 bedroom · 2 ...     130907
# 11  462072  Rental unit in Madrid · ★4.93 · 2 bedrooms · 4...    2296476
# ...

# %%
data
# Out:
#                        id                                               name  \
# 0                    6369  Rental unit in Madrid · ★4.87 · 1 bedroom · 1 ...
# 1                   21853  Rental unit in Madrid · ★4.58 · 1 bedroom · 1 ...
# 2                  451174  casa particular in Madrid · ★4.71 · 1 bedroom ...
# 3                   24805  Rental unit in Madrid · ★4.90 · 6 bedrooms · 1...
# 4                  456165  Guest suite in Madrid · ★5.0 · 1 bedroom · 1 b...
# ...                   ...                                                ...
# 23519  908757271360095110  Rental unit in Madrid · ★New · 2 bedrooms · 2 ...
# 23520  908768034188159973  Rental unit in Madrid · ★New · 3 bedrooms · 3 ...
# 23521  908772325334371147  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 23522  908774672501330570  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 23523  908784742161639676  Rental unit in Madrid · ★New · 2 bedrooms · 2 ...
#
# ...

# %%
data.head(5)
# Out:
#        id                                               name    host_id  \
# 0    6369  Rental unit in Madrid · ★4.87 · 1 bedroom · 1 ...      13660
# 1   21853  Rental unit in Madrid · ★4.58 · 1 bedroom · 1 ...      83531
# 2  451174  casa particular in Madrid · ★4.71 · 1 bedroom ...    2240898
# 3   24805  Rental unit in Madrid · ★4.90 · 6 bedrooms · 1...  346366726
# 4  456165  Guest suite in Madrid · ★5.0 · 1 bedroom · 1 b...     617086
#
#    host_name neighbourhood_group   neighbourhood   latitude  longitude  \
# 0      Simon           Chamartín  Hispanoamérica  40.457240  -3.676880
# 1      Abdel              Latina        Cármenes  40.403810  -3.741300
# 2  Alejandro            Chamberí         Almagro  40.434551  -3.698387
# 3     Alvaro              Centro     Universidad  40.421830  -3.705290
# 4      Agata         Carabanchel        Comillas  40.390320  -3.713820
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data.tail(5)
# Out:
#                        id                                               name  \
# 23519  908757271360095110  Rental unit in Madrid · ★New · 2 bedrooms · 2 ...
# 23520  908768034188159973  Rental unit in Madrid · ★New · 3 bedrooms · 3 ...
# 23521  908772325334371147  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 23522  908774672501330570  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 23523  908784742161639676  Rental unit in Madrid · ★New · 2 bedrooms · 2 ...
#
#          host_id  host_name neighbourhood_group neighbourhood   latitude  \
# 23519  518713670   Bemadrid              Centro   Embajadores  40.409300
# 23520  518713670   Bemadrid   Moncloa - Aravaca     Argüelles  40.430675
# 23521  460488106  Alexander             Barajas         Timón  40.471325
# 23522  518713670   Bemadrid           Chamartín      Castilla  40.470550
# 23523  518713670   Bemadrid           Salamanca         Lista  40.431580
#
# ...

# %%
data.shape
# Out:
# (23524, 18)

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              23524 non-null  int64
#  1   name                            23524 non-null  object
#  2   host_id                         23524 non-null  int64
#  3   host_name                       23521 non-null  object
#  4   neighbourhood_group             23524 non-null  object
#  5   neighbourhood                   23524 non-null  object
#  6   latitude                        23524 non-null  float64
#  7   longitude                       23524 non-null  float64
#  8   room_type                       23524 non-null  object
#  9   price                           23524 non-null  int64
#  10  minimum_nights                  23524 non-null  int64
#  11  number_of_reviews               23524 non-null  int64
# ...

# %%
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.352400e+04  2.352400e+04  23524.000000  23524.000000  23524.000000
# mean   3.042946e+17  1.961414e+08     40.421424     -3.694248    149.095690
# std    3.772467e+17  1.713861e+08      0.023056      0.027727    973.954275
# min    6.369000e+03  7.952000e+03     40.331397     -3.835330      0.000000
# 25%    2.705431e+07  3.586593e+07     40.409523     -3.707461     50.000000
# 50%    4.842274e+07  1.398005e+08     40.420075     -3.701150     89.000000
# 75%    7.158394e+17  3.488715e+08     40.431062     -3.685967    143.000000
# max    9.100071e+17  5.188792e+08     40.536230     -3.543760  85110.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    23524.000000       23524.000000       18505.000000
# mean         7.463569          41.826560           1.773514
# std         33.011152          78.693929           1.877412
# ...

# %% [markdown]
# ## Data visualization
#
# 1. Grafico de barras
# 2. Grafico de líneas
# 3. Grafico de cajas y bigotes (boxplot)
#
# **Buscar hacer estos graficos con Matplotlib y Seaborn (librerias de Python)**
#
# **Escribir en markdown una interpretacion de los graficos que hemos hecho**
#
# ¿Que significa este dato?
#
# ¿Que importancia tiene este dato o este grafico para el negocio de Airbnb?B?)**

# %%
# Obtener conteo de valores únicos en la columna 'neighbourhood_group'
plt.plot(df_airbnb['neighbourhood_group'].value_counts()

# Crear gráfico de barras
value_counts.plot.bar()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Obtener conteo de valores únicos en la columna 'neighbourhood_group'
# ----> 2 value_counts = df_airbnb['neighbourhood_group'].value_counts()
#       4 # Crear gráfico de barras
#       5 value_counts.plot.bar()
#
# NameError: name 'df_airbnb' is not defined

# %%
df_airbnb=pd.DataFrame(data,columns = ['neighbourhood_group' , 'neighbourhood' , 'room_type' , 'price' ,'minimum_nights','number_of_reviews'])

# %%
df_airbnb
# Out:
#       neighbourhood_group   neighbourhood        room_type  price  \
# 0               Chamartín  Hispanoamérica     Private room     90
# 1                  Latina        Cármenes     Private room     31
# 2                Chamberí         Almagro     Private room     47
# 3                  Centro     Universidad  Entire home/apt     92
# 4             Carabanchel        Comillas     Private room     30
# ...                   ...             ...              ...    ...
# 23519              Centro     Embajadores  Entire home/apt    128
# 23520   Moncloa - Aravaca       Argüelles  Entire home/apt    129
# 23521             Barajas           Timón     Private room     33
# 23522           Chamartín        Castilla  Entire home/apt    100
# 23523           Salamanca           Lista  Entire home/apt     92
#
#        minimum_nights  number_of_reviews
# 0                   4                104
# 1                   4                 33
# 2                   3                 33
# ...

# %%
# Obtener conteo de valores únicos en la columna 'neighbourhood_group'
value_counts = df_airbnb['neighbourhood_group'].value_counts()

# Crear gráfico de barras
value_counts.plot.bar()

# Mostrar el gráfico
plt.show()

# %%
# Obtener conteo de valores únicos en la columna 'neighbourhood_group'
plt.plot(df_airbnb['neighbourhood_group'], df_airbnb['minimum_nights'])

# Mostrar el gráfico
plt.show()

# %%
# crear grafico de líneas utilizando las columnas room_type y minimun nights
plt.plot(df_airbnb['room_type'], df_airbnb['minimum_nights'])

# Mostrar el gráfico
plt.show()

# %%
# crear grafico de líneas utilizando las columnas room_type y minimun nights
plt.plot( df_airbnb['minimum_nights'], df_airbnb['price'])

# Mostrar el gráfico
plt.show()
